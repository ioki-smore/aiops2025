# %%
import pandas as pd # type: ignore
import json
import glob

files = glob.glob("../phasetwo/2025-06-18/log-parquet/*.parquet")
structured = open("error.06-18.log", "w", encoding="utf-8")
for log in files:
    df = pd.read_parquet(log)
    # df = pd.read_parquet("../data/sample/normal/log-parquet/" + log)
    print(f"Processing {log} with {len(df)} records")

    # 逐行打印message列的内容
    for index, row in df.iterrows():
        if 'message' in row:
            message = row['message']
            if not message.startswith('{"'):
                continue
            message = json.loads(message)
            if 'error' in message:
                structured.write(f"Row {index}: {message}\n")
            # elif 'session' in message:
            #     print(message['session'])
        else:
            print(row)
# print(f"k8_namespace\t{row['k8_namespace']}\ntimestamp\t{row['@timestamp']}\nagent_name\t{row['agent_name']}\nk8_pod\t{row['k8_pod']}\nmessage\t{row['message']}\nk8_node_name\t{row['k8_node_name']}")
# print(row)

# %%
import pandas as pd
import json
import glob
import os

# Find all date folders (assuming they follow the pattern ../phasetwo/YYYY-MM-DD/)
date_folders = glob.glob("../phasetwo/*/")  # Gets all directories in phasetwo

for date_folder in date_folders:
    # Extract date from folder path (assuming format ../phasetwo/YYYY-MM-DD/)
    date = os.path.basename(os.path.normpath(date_folder))

    # Skip if not in YYYY-MM-DD format
    if len(date) != 10 or date[4] != '-' or date[7] != '-':
        continue

    # Find all parquet files for this date
    parquet_files = glob.glob(f"{date_folder}/log-parquet/*.parquet")

    if not parquet_files:
        print(f"No parquet files found for date {date}")
        continue

    # Create error log file for this date
    error_log_path = f"error-{date}.log"
    print(f"Processing date {date}, output to {error_log_path}")

    with open(error_log_path, "w", encoding="utf-8") as structured:
        for log_file in parquet_files:
            try:
                df = pd.read_parquet(log_file)
                print(f"  Processing {os.path.basename(log_file)} with {len(df)} records")

                for index, row in df.iterrows():
                    if 'message' in row:
                        message = row['message']
                        if not isinstance(message, str) or not message.startswith('{"'):
                            continue
                        try:
                            message_json = json.loads(message)
                            if 'error' in message_json:
                                structured.write(f"File: {os.path.basename(log_file)}, Row {index}: {message_json}\n")
                        except json.JSONDecodeError:
                            continue
            except Exception as e:
                print(f"Error processing {log_file}: {str(e)}")

    print(f"Finished processing date {date}\n")
# Out:
# Processing date 2025-06-20, output to error-2025-06-20.log
#   Processing log_filebeat-server_2025-06-20_11-00-00.parquet with 458782 records
#   Processing log_filebeat-server_2025-06-20_22-00-00.parquet with 155634 records
#   Processing log_filebeat-server_2025-06-20_06-00-00.parquet with 127235 records
#   Processing log_filebeat-server_2025-06-20_10-00-00.parquet with 379589 records
#   Processing log_filebeat-server_2025-06-20_12-00-00.parquet with 320925 records
#   Processing log_filebeat-server_2025-06-20_05-00-00.parquet with 156744 records
#   Processing log_filebeat-server_2025-06-20_14-00-00.parquet with 358944 records
#   Processing log_filebeat-server_2025-06-20_04-00-00.parquet with 158182 records
#   Processing log_filebeat-server_2025-06-20_20-00-00.parquet with 382684 records
#   Processing log_filebeat-server_2025-06-20_23-00-00.parquet with 152935 records
#   Processing log_filebeat-server_2025-06-20_02-00-00.parquet with 141808 records
#   Processing log_filebeat-server_2025-06-20_13-00-00.parquet with 348172 records
#   Processing log_filebeat-server_2025-06-20_00-00-00.parquet with 157774 records
#   Processing log_filebeat-server_2025-06-20_19-00-00.parquet with 582851 records
#   Processing log_filebeat-server_2025-06-20_08-00-00.parquet with 155081 records
#   Processing log_filebeat-server_2025-06-20_07-00-00.parquet with 149028 records
#   Processing log_filebeat-server_2025-06-20_03-00-00.parquet with 121292 records
#   Processing log_filebeat-server_2025-06-20_21-00-00.parquet with 298488 records
#   Processing log_filebeat-server_2025-06-20_17-00-00.parquet with 456845 records
#   Processing log_filebeat-server_2025-06-20_01-00-00.parquet with 155812 records
#   Processing log_filebeat-server_2025-06-20_15-00-00.parquet with 355380 records
#   Processing log_filebeat-server_2025-06-20_09-00-00.parquet with 210149 records
#   Processing log_filebeat-server_2025-06-20_18-00-00.parquet with 401160 records
#   Processing log_filebeat-server_2025-06-20_16-00-00.parquet with 422335 records
# Finished processing date 2025-06-20
#
# Processing date 2025-06-17, output to error-2025-06-17.log
#   Processing log_filebeat-server_2025-06-17_15-00-00.parquet with 409175 records
#   Processing log_filebeat-server_2025-06-17_20-00-00.parquet with 354818 records
#   Processing log_filebeat-server_2025-06-17_17-00-00.parquet with 543510 records
#   Processing log_filebeat-server_2025-06-17_11-00-00.parquet with 381980 records
#   Processing log_filebeat-server_2025-06-17_01-00-00.parquet with 110149 records
#   Processing log_filebeat-server_2025-06-17_13-00-00.parquet with 463036 records
#   Processing log_filebeat-server_2025-06-17_23-00-00.parquet with 156787 records
#   Processing log_filebeat-server_2025-06-17_10-00-00.parquet with 143191 records
#   Processing log_filebeat-server_2025-06-17_12-00-00.parquet with 482916 records
#   Processing log_filebeat-server_2025-06-17_14-00-00.parquet with 459379 records
#   Processing log_filebeat-server_2025-06-17_19-00-00.parquet with 583112 records
#   Processing log_filebeat-server_2025-06-17_03-00-00.parquet with 156253 records
#   Processing log_filebeat-server_2025-06-17_00-00-00.parquet with 155012 records
#   Processing log_filebeat-server_2025-06-17_18-00-00.parquet with 576880 records
#   Processing log_filebeat-server_2025-06-17_21-00-00.parquet with 304092 records
#   Processing log_filebeat-server_2025-06-17_02-00-00.parquet with 153178 records
#   Processing log_filebeat-server_2025-06-17_16-00-00.parquet with 503815 records
#   Processing log_filebeat-server_2025-06-17_22-00-00.parquet with 154725 records
# Finished processing date 2025-06-17
#
# Processing date 2025-06-27, output to error-2025-06-27.log
#   Processing log_filebeat-server_2025-06-27_21-00-00.parquet with 307046 records
#   Processing log_filebeat-server_2025-06-27_03-00-00.parquet with 157219 records
#   Processing log_filebeat-server_2025-06-27_12-00-00.parquet with 462312 records
#   Processing log_filebeat-server_2025-06-27_23-00-00.parquet with 156593 records
#   Processing log_filebeat-server_2025-06-27_18-00-00.parquet with 514468 records
#   Processing log_filebeat-server_2025-06-27_07-00-00.parquet with 112742 records
#   Processing log_filebeat-server_2025-06-27_17-00-00.parquet with 522804 records
#   Processing log_filebeat-server_2025-06-27_10-00-00.parquet with 351909 records
#   Processing log_filebeat-server_2025-06-27_14-00-00.parquet with 456180 records
#   Processing log_filebeat-server_2025-06-27_22-00-00.parquet with 153736 records
#   Processing log_filebeat-server_2025-06-27_20-00-00.parquet with 506272 records
#   Processing log_filebeat-server_2025-06-27_09-00-00.parquet with 205324 records
#   Processing log_filebeat-server_2025-06-27_16-00-00.parquet with 503350 records
#   Processing log_filebeat-server_2025-06-27_01-00-00.parquet with 157647 records
#   Processing log_filebeat-server_2025-06-27_11-00-00.parquet with 459305 records
#   Processing log_filebeat-server_2025-06-27_00-00-00.parquet with 160278 records
#   Processing log_filebeat-server_2025-06-27_19-00-00.parquet with 565474 records
#   Processing log_filebeat-server_2025-06-27_13-00-00.parquet with 467229 records
#   Processing log_filebeat-server_2025-06-27_15-00-00.parquet with 333978 records
#   Processing log_filebeat-server_2025-06-27_06-00-00.parquet with 156435 records
#   Processing log_filebeat-server_2025-06-27_05-00-00.parquet with 158155 records
#   Processing log_filebeat-server_2025-06-27_04-00-00.parquet with 128525 records
#   Processing log_filebeat-server_2025-06-27_02-00-00.parquet with 152851 records
#   Processing log_filebeat-server_2025-06-27_08-00-00.parquet with 156380 records
# Finished processing date 2025-06-27
#
# Processing date 2025-06-24, output to error-2025-06-24.log
#   Processing log_filebeat-server_2025-06-24_08-00-00.parquet with 115641 records
#   Processing log_filebeat-server_2025-06-24_03-00-00.parquet with 153396 records
#   Processing log_filebeat-server_2025-06-24_10-00-00.parquet with 380758 records
#   Processing log_filebeat-server_2025-06-24_06-00-00.parquet with 156603 records
#   Processing log_filebeat-server_2025-06-24_15-00-00.parquet with 474004 records
#   Processing log_filebeat-server_2025-06-24_21-00-00.parquet with 126543 records
#   Processing log_filebeat-server_2025-06-24_14-00-00.parquet with 468760 records
#   Processing log_filebeat-server_2025-06-24_19-00-00.parquet with 579362 records
#   Processing log_filebeat-server_2025-06-24_16-00-00.parquet with 502187 records
#   Processing log_filebeat-server_2025-06-24_09-00-00.parquet with 209602 records
#   Processing log_filebeat-server_2025-06-24_04-00-00.parquet with 156325 records
#   Processing log_filebeat-server_2025-06-24_20-00-00.parquet with 505756 records
#   Processing log_filebeat-server_2025-06-24_01-00-00.parquet with 156791 records
#   Processing log_filebeat-server_2025-06-24_11-00-00.parquet with 462269 records
#   Processing log_filebeat-server_2025-06-24_02-00-00.parquet with 157436 records
#   Processing log_filebeat-server_2025-06-24_12-00-00.parquet with 487335 records
#   Processing log_filebeat-server_2025-06-24_18-00-00.parquet with 581282 records
#   Processing log_filebeat-server_2025-06-24_00-00-00.parquet with 128142 records
#   Processing log_filebeat-server_2025-06-24_05-00-00.parquet with 158326 records
#   Processing log_filebeat-server_2025-06-24_17-00-00.parquet with 548133 records
#   Processing log_filebeat-server_2025-06-24_22-00-00.parquet with 133738 records
#   Processing log_filebeat-server_2025-06-24_23-00-00.parquet with 128658 records
#   Processing log_filebeat-server_2025-06-24_07-00-00.parquet with 156654 records
#   Processing log_filebeat-server_2025-06-24_13-00-00.parquet with 469482 records
# Finished processing date 2025-06-24
#
# Processing date 2025-06-19, output to error-2025-06-19.log
#   Processing log_filebeat-server_2025-06-19_13-00-00.parquet with 400862 records
#   Processing log_filebeat-server_2025-06-19_17-00-00.parquet with 544870 records
#   Processing log_filebeat-server_2025-06-19_10-00-00.parquet with 319274 records
#   Processing log_filebeat-server_2025-06-19_04-00-00.parquet with 157179 records
#   Processing log_filebeat-server_2025-06-19_12-00-00.parquet with 485108 records
#   Processing log_filebeat-server_2025-06-19_21-00-00.parquet with 229452 records
#   Processing log_filebeat-server_2025-06-19_19-00-00.parquet with 519605 records
#   Processing log_filebeat-server_2025-06-19_01-00-00.parquet with 133727 records
#   Processing log_filebeat-server_2025-06-19_03-00-00.parquet with 110995 records
#   Processing log_filebeat-server_2025-06-19_02-00-00.parquet with 141019 records
#   Processing log_filebeat-server_2025-06-19_11-00-00.parquet with 457103 records
#   Processing log_filebeat-server_2025-06-19_06-00-00.parquet with 156263 records
#   Processing log_filebeat-server_2025-06-19_16-00-00.parquet with 494343 records
#   Processing log_filebeat-server_2025-06-19_20-00-00.parquet with 503984 records
#   Processing log_filebeat-server_2025-06-19_09-00-00.parquet with 198086 records
#   Processing log_filebeat-server_2025-06-19_22-00-00.parquet with 155974 records
#   Processing log_filebeat-server_2025-06-19_05-00-00.parquet with 154024 records
#   Processing log_filebeat-server_2025-06-19_15-00-00.parquet with 431470 records
#   Processing log_filebeat-server_2025-06-19_00-00-00.parquet with 157883 records
#   Processing log_filebeat-server_2025-06-19_07-00-00.parquet with 101105 records
#   Processing log_filebeat-server_2025-06-19_14-00-00.parquet with 358358 records
#   Processing log_filebeat-server_2025-06-19_08-00-00.parquet with 156160 records
#   Processing log_filebeat-server_2025-06-19_18-00-00.parquet with 534683 records
#   Processing log_filebeat-server_2025-06-19_23-00-00.parquet with 155875 records
# Finished processing date 2025-06-19
#
# Processing date 2025-06-21, output to error-2025-06-21.log
#   Processing log_filebeat-server_2025-06-21_23-00-00.parquet with 153207 records
#   Processing log_filebeat-server_2025-06-21_06-00-00.parquet with 154309 records
#   Processing log_filebeat-server_2025-06-21_04-00-00.parquet with 156323 records
#   Processing log_filebeat-server_2025-06-21_20-00-00.parquet with 487051 records
#   Processing log_filebeat-server_2025-06-21_10-00-00.parquet with 385250 records
#   Processing log_filebeat-server_2025-06-21_09-00-00.parquet with 164422 records
#   Processing log_filebeat-server_2025-06-21_19-00-00.parquet with 542802 records
#   Processing log_filebeat-server_2025-06-21_11-00-00.parquet with 454115 records
#   Processing log_filebeat-server_2025-06-21_08-00-00.parquet with 132608 records
#   Processing log_filebeat-server_2025-06-21_12-00-00.parquet with 312033 records
#   Processing log_filebeat-server_2025-06-21_15-00-00.parquet with 400296 records
#   Processing log_filebeat-server_2025-06-21_01-00-00.parquet with 156875 records
#   Processing log_filebeat-server_2025-06-21_02-00-00.parquet with 132445 records
#   Processing log_filebeat-server_2025-06-21_14-00-00.parquet with 456554 records
#   Processing log_filebeat-server_2025-06-21_16-00-00.parquet with 500343 records
#   Processing log_filebeat-server_2025-06-21_17-00-00.parquet with 546816 records
#   Processing log_filebeat-server_2025-06-21_03-00-00.parquet with 157365 records
#   Processing log_filebeat-server_2025-06-21_21-00-00.parquet with 239870 records
#   Processing log_filebeat-server_2025-06-21_13-00-00.parquet with 424225 records
#   Processing log_filebeat-server_2025-06-21_07-00-00.parquet with 150372 records
#   Processing log_filebeat-server_2025-06-21_18-00-00.parquet with 356947 records
#   Processing log_filebeat-server_2025-06-21_22-00-00.parquet with 140204 records
#   Processing log_filebeat-server_2025-06-21_05-00-00.parquet with 157152 records
#   Processing log_filebeat-server_2025-06-21_00-00-00.parquet with 158121 records
# Finished processing date 2025-06-21
#
# Processing date 2025-06-28, output to error-2025-06-28.log
#   Processing log_filebeat-server_2025-06-28_15-00-00.parquet with 475003 records
#   Processing log_filebeat-server_2025-06-28_12-00-00.parquet with 483602 records
#   Processing log_filebeat-server_2025-06-28_09-00-00.parquet with 209570 records
#   Processing log_filebeat-server_2025-06-28_18-00-00.parquet with 582253 records
#   Processing log_filebeat-server_2025-06-28_02-00-00.parquet with 156879 records
#   Processing log_filebeat-server_2025-06-28_07-00-00.parquet with 140534 records
#   Processing log_filebeat-server_2025-06-28_01-00-00.parquet with 156385 records
#   Processing log_filebeat-server_2025-06-28_21-00-00.parquet with 289481 records
#   Processing log_filebeat-server_2025-06-28_04-00-00.parquet with 156545 records
#   Processing log_filebeat-server_2025-06-28_23-00-00.parquet with 124761 records
#   Processing log_filebeat-server_2025-06-28_08-00-00.parquet with 122913 records
#   Processing log_filebeat-server_2025-06-28_13-00-00.parquet with 468356 records
#   Processing log_filebeat-server_2025-06-28_14-00-00.parquet with 471057 records
#   Processing log_filebeat-server_2025-06-28_19-00-00.parquet with 578893 records
#   Processing log_filebeat-server_2025-06-28_22-00-00.parquet with 136175 records
#   Processing log_filebeat-server_2025-06-28_00-00-00.parquet with 152349 records
#   Processing log_filebeat-server_2025-06-28_06-00-00.parquet with 157224 records
#   Processing log_filebeat-server_2025-06-28_11-00-00.parquet with 458322 records
#   Processing log_filebeat-server_2025-06-28_10-00-00.parquet with 383227 records
#   Processing log_filebeat-server_2025-06-28_20-00-00.parquet with 474531 records
#   Processing log_filebeat-server_2025-06-28_17-00-00.parquet with 422519 records
#   Processing log_filebeat-server_2025-06-28_16-00-00.parquet with 496219 records
#   Processing log_filebeat-server_2025-06-28_05-00-00.parquet with 148691 records
#   Processing log_filebeat-server_2025-06-28_03-00-00.parquet with 145187 records
# Finished processing date 2025-06-28
#
# Processing date 2025-06-29, output to error-2025-06-29.log
#   Processing log_filebeat-server_2025-06-29_17-00-00.parquet with 701535 records
#   Processing log_filebeat-server_2025-06-29_11-00-00.parquet with 596299 records
#   Processing log_filebeat-server_2025-06-29_22-00-00.parquet with 104251 records
#   Processing log_filebeat-server_2025-06-29_16-00-00.parquet with 649051 records
#   Processing log_filebeat-server_2025-06-29_23-00-00.parquet with 157663 records
#   Processing log_filebeat-server_2025-06-29_10-00-00.parquet with 531239 records
#   Processing log_filebeat-server_2025-06-29_02-00-00.parquet with 315556 records
#   Processing log_filebeat-server_2025-06-29_20-00-00.parquet with 521596 records
#   Processing log_filebeat-server_2025-06-29_00-00-00.parquet with 293929 records
#   Processing log_filebeat-server_2025-06-29_15-00-00.parquet with 455356 records
#   Processing log_filebeat-server_2025-06-29_09-00-00.parquet with 367729 records
#   Processing log_filebeat-server_2025-06-29_18-00-00.parquet with 569932 records
#   Processing log_filebeat-server_2025-06-29_01-00-00.parquet with 314209 records
#   Processing log_filebeat-server_2025-06-29_13-00-00.parquet with 516352 records
#   Processing log_filebeat-server_2025-06-29_07-00-00.parquet with 314435 records
#   Processing log_filebeat-server_2025-06-29_04-00-00.parquet with 279653 records
#   Processing log_filebeat-server_2025-06-29_05-00-00.parquet with 317529 records
#   Processing log_filebeat-server_2025-06-29_08-00-00.parquet with 316011 records
#   Processing log_filebeat-server_2025-06-29_14-00-00.parquet with 610331 records
#   Processing log_filebeat-server_2025-06-29_21-00-00.parquet with 212795 records
#   Processing log_filebeat-server_2025-06-29_03-00-00.parquet with 306899 records
#   Processing log_filebeat-server_2025-06-29_12-00-00.parquet with 642293 records
#   Processing log_filebeat-server_2025-06-29_19-00-00.parquet with 668859 records
#   Processing log_filebeat-server_2025-06-29_06-00-00.parquet with 299032 records
# Finished processing date 2025-06-29
#
# Processing date 2025-06-18, output to error-2025-06-18.log
#   Processing log_filebeat-server_2025-06-18_00-00-00.parquet with 157784 records
#   Processing log_filebeat-server_2025-06-18_18-00-00.parquet with 568674 records
#   Processing log_filebeat-server_2025-06-18_20-00-00.parquet with 503904 records
#   Processing log_filebeat-server_2025-06-18_07-00-00.parquet with 151178 records
#   Processing log_filebeat-server_2025-06-18_01-00-00.parquet with 157640 records
#   Processing log_filebeat-server_2025-06-18_23-00-00.parquet with 136694 records
#   Processing log_filebeat-server_2025-06-18_02-00-00.parquet with 153954 records
#   Processing log_filebeat-server_2025-06-18_14-00-00.parquet with 467021 records
#   Processing log_filebeat-server_2025-06-18_15-00-00.parquet with 474795 records
#   Processing log_filebeat-server_2025-06-18_17-00-00.parquet with 544988 records
#   Processing log_filebeat-server_2025-06-18_22-00-00.parquet with 126075 records
#   Processing log_filebeat-server_2025-06-18_16-00-00.parquet with 500771 records
#   Processing log_filebeat-server_2025-06-18_10-00-00.parquet with 328098 records
#   Processing log_filebeat-server_2025-06-18_21-00-00.parquet with 301336 records
#   Processing log_filebeat-server_2025-06-18_13-00-00.parquet with 464770 records
#   Processing log_filebeat-server_2025-06-18_12-00-00.parquet with 481079 records
#   Processing log_filebeat-server_2025-06-18_04-00-00.parquet with 155712 records
#   Processing log_filebeat-server_2025-06-18_11-00-00.parquet with 342683 records
#   Processing log_filebeat-server_2025-06-18_03-00-00.parquet with 139896 records
#   Processing log_filebeat-server_2025-06-18_19-00-00.parquet with 581193 records
#   Processing log_filebeat-server_2025-06-18_08-00-00.parquet with 142536 records
#   Processing log_filebeat-server_2025-06-18_06-00-00.parquet with 98173 records
#   Processing log_filebeat-server_2025-06-18_09-00-00.parquet with 207511 records
#   Processing log_filebeat-server_2025-06-18_05-00-00.parquet with 137628 records
# Finished processing date 2025-06-18

# %%
import re

error_str = "failed to complete the order: rpc error: code = Internal desc = cart failure: failed to get user cart during checkout: rpc error: code = Unavailable desc = connection error: desc = \"transport: Error while dialing dial tcp: lookup cartservice on 10.233.33.139:53: server misbehaving\""
import re
import pandas as pd

def extract_key_info(error: str):
    if not isinstance(error, str):
        return pd.Series([None, None, None])

    # 1. 提取服务名和IP
    service_ip_pattern = r'(\w+)\s+on\s+(\d+\.\d+\.\d+\.\d+:\d+)'
    service_ip_match = re.search(service_ip_pattern, error)
    service = service_ip_match.group(1) if service_ip_match else None
    ip = service_ip_match.group(2) if service_ip_match else None

    # 2. 提取操作描述，尝试匹配 "failed to ..." 到下一个冒号或句号之前的内容
    operation_pattern = r'failed to ([^:]+)'
    operation_match = re.search(operation_pattern, error)
    operation = operation_match.group(1).strip() if operation_match else None

    return pd.Series([service, ip, operation])

print(extract_key_info(error_str))
# Out:
# 0           cartservice
# 1      10.233.33.139:53
# 2    complete the order
# dtype: object

# %%
import pandas as pd
import json
import glob

def normalize_error(error: str) -> str:
    if not isinstance(error, str):
        return error

    # 先替换以#开头的ID
    error = re.sub(r'#\w+', '<PRODUCT_ID>', error)

    # 再替换不带#的产品ID，假设是8-12位大写字母数字组合
    error = re.sub(r'\b[A-Z0-9]{8,12}\b', '<PRODUCT_ID>', error)

    return error

error_logs = []
files = glob.glob("../phasetwo/*/log-parquet/*.parquet")  # Gets all directories in phasetwo
for file in files:
    try:
        df = pd.read_parquet(file)
        print(f"Processing {file} with {len(df)} records")

        for index, row in df.iterrows():
            if 'message' in row:
                message = row['message']
                if not isinstance(message, str) or not message.startswith('{"'):
                    continue
                try:
                    message_json = json.loads(message)
                    if 'error' in message_json:
                        msg = normalize_error(message_json['error'])
                        if msg not in error_logs:
                            error_logs.append(msg)
                            print(msg)
                except json.JSONDecodeError:
                    continue
    except Exception as e:
        print(f"Error processing {log_file}: {str(e)}")
# with open("error_logs.txt", "w", encoding="utf-8") as error_logs:
#     error_logs.write("\n".join(error_logs))
# Out:
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_11-00-00.parquet with 458782 records
# failed to complete the order: rpc error: code = Internal desc = failed to charge card: could not charge the card: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp 10.233.55.4:50051: connect: connection refused"
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_22-00-00.parquet with 155634 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_06-00-00.parquet with 127235 records
# could not retrieve product: rpc error: code = Unknown desc = Error 9005 (HY000): Region is unavailable
# failed to complete the order: rpc error: code = Internal desc = failed to prepare order: failed to get product #"<PRODUCT_ID>"
# failed to get product recommendations: failed to get recommended product info (<PRODUCT_ID>): rpc error: code = Unknown desc = Error 9005 (HY000): Region is unavailable
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_10-00-00.parquet with 379589 records
# failed to complete the order: rpc error: code = Internal desc = shipping quote failure: failed to get shipping quote: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp: lookup shippingservice on 10.233.33.139:53: server misbehaving"
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_12-00-00.parquet with 320925 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_05-00-00.parquet with 156744 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_14-00-00.parquet with 358944 records
# could not retrieve cart: rpc error: code = Canceled desc = context canceled
# failed to add to cart: rpc error: code = Canceled desc = context canceled
# could not retrieve cart: rpc error: code = Unavailable desc = transport is closing
# could not retrieve cart: rpc error: code = Unavailable desc = timed out waiting for server handshake
# failed to add to cart: rpc error: code = Unavailable desc = timed out waiting for server handshake
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_04-00-00.parquet with 158182 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_20-00-00.parquet with 382684 records
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5437ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 15, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495456, serverEndpoint: redis-cart:6379, conn-sec: 211393.29, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=1,CompletedItems=8301821,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5643ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 15, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495456, serverEndpoint: redis-cart:6379, conn-sec: 211393.29, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8301821,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5532ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 17, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495458, serverEndpoint: redis-cart:6379, conn-sec: 211394.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=2,CompletedItems=8301863,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5690ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 17, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495458, serverEndpoint: redis-cart:6379, conn-sec: 211394.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=1,CompletedItems=8301863,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5592ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 11, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81920, serverEndpoint: redis-cart:6379, conn-sec: 211363.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407007,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5870ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 11, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81920, serverEndpoint: redis-cart:6379, conn-sec: 211363.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407007,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5405ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 19, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495460, serverEndpoint: redis-cart:6379, conn-sec: 211395.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=1,CompletedItems=8301880,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5354ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495462, serverEndpoint: redis-cart:6379, conn-sec: 211396.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=2,CompletedItems=8301896,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5701ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495462, serverEndpoint: redis-cart:6379, conn-sec: 211396.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8301896,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5551ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495462, serverEndpoint: redis-cart:6379, conn-sec: 211396.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=1,CompletedItems=8301896,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.AddItemAsync(String userId, String productId, Int32 quantity) in /app/cartstore/RedisCartStore.cs:line 203
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5873ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 25, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495466, serverEndpoint: redis-cart:6379, conn-sec: 211399.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8301963,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5742ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 28, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495469, serverEndpoint: redis-cart:6379, conn-sec: 211400.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8301983,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5988ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 31, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495472, serverEndpoint: redis-cart:6379, conn-sec: 211401.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302004,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5582ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 36, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495477, serverEndpoint: redis-cart:6379, conn-sec: 211403.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=1,CompletedItems=8302062,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5977ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 36, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495477, serverEndpoint: redis-cart:6379, conn-sec: 211403.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302062,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5983ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81930, serverEndpoint: redis-cart:6379, conn-sec: 211374.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407178,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5978ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 38, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495479, serverEndpoint: redis-cart:6379, conn-sec: 211404.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302103,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.AddItemAsync(String userId, String productId, Int32 quantity) in /app/cartstore/RedisCartStore.cs:line 203
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5973ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81930, serverEndpoint: redis-cart:6379, conn-sec: 211375.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=1,CompletedItems=2407183,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5974ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81930, serverEndpoint: redis-cart:6379, conn-sec: 211375.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407183,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5975ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 21, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81930, serverEndpoint: redis-cart:6379, conn-sec: 211375.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407183,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.AddItemAsync(String userId, String productId, Int32 quantity) in /app/cartstore/RedisCartStore.cs:line 203
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5984ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 39, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495480, serverEndpoint: redis-cart:6379, conn-sec: 211405.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302114,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5975ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 39, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495480, serverEndpoint: redis-cart:6379, conn-sec: 211405.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302114,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5955ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 39, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495480, serverEndpoint: redis-cart:6379, conn-sec: 211405.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302114,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5981ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 22, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81931, serverEndpoint: redis-cart:6379, conn-sec: 211376.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407196,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to complete the order: rpc error: code = Internal desc = cart failure: failed to get user cart during checkout: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5656ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 41, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495482, serverEndpoint: redis-cart:6379, conn-sec: 211407.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8302142,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5965ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 26, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81935, serverEndpoint: redis-cart:6379, conn-sec: 211378.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407238,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5970ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 26, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81935, serverEndpoint: redis-cart:6379, conn-sec: 211378.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407238,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5979ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 27, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81936, serverEndpoint: redis-cart:6379, conn-sec: 211379.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407264,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5980ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 49, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495490, serverEndpoint: redis-cart:6379, conn-sec: 211410.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=8302240,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5977ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 29, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81938, serverEndpoint: redis-cart:6379, conn-sec: 211383.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407315,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5978ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 58, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495499, serverEndpoint: redis-cart:6379, conn-sec: 211414.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=8302326,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5986ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 69, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495510, serverEndpoint: redis-cart:6379, conn-sec: 211421.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=6,QueuedItems=0,CompletedItems=8302437,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5988ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 69, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495510, serverEndpoint: redis-cart:6379, conn-sec: 211421.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=6,QueuedItems=0,CompletedItems=8302437,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5982ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 69, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495510, serverEndpoint: redis-cart:6379, conn-sec: 211421.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=6,QueuedItems=1,CompletedItems=8302437,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.AddItemAsync(String userId, String productId, Int32 quantity) in /app/cartstore/RedisCartStore.cs:line 203
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5974ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 40, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81949, serverEndpoint: redis-cart:6379, conn-sec: 211391.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407479,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5987ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 73, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495514, serverEndpoint: redis-cart:6379, conn-sec: 211422.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=7,QueuedItems=0,CompletedItems=8302471,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5987ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 73, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495514, serverEndpoint: redis-cart:6379, conn-sec: 211422.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=7,QueuedItems=0,CompletedItems=8302471,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5987ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 75, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495516, serverEndpoint: redis-cart:6379, conn-sec: 211423.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=7,QueuedItems=0,CompletedItems=8302487,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5981ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 42, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81951, serverEndpoint: redis-cart:6379, conn-sec: 211393.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=3,Free=32764,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407515,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.AddItemAsync(String userId, String productId, Int32 quantity) in /app/cartstore/RedisCartStore.cs:line 203
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5978ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 42, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81951, serverEndpoint: redis-cart:6379, conn-sec: 211393.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=4,Free=32763,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=1,CompletedItems=2407515,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5314ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 42, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81951, serverEndpoint: redis-cart:6379, conn-sec: 211393.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=4,Free=32763,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=2,CompletedItems=2407515,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# failed to complete the order: rpc error: code = Internal desc = cart failure: failed to get user cart during checkout: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5985ms elapsed, timeout is 5000ms), command=HGET, next: HGET 87861a83-f9b0-4204-aa5e-14f404ee2f3d, inst: 0, qu: 0, qs: 42, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 81951, serverEndpoint: redis-cart:6379, conn-sec: 211393.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=5,QueuedItems=0,CompletedItems=2407515,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=1KiB, inbound=0KiB, 5981ms elapsed, timeout is 5000ms), command=HGET, next: HGET 7693bff1-86fd-4e88-aa26-6cdf89de0bbc, inst: 0, qu: 0, qs: 85, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 495525, serverEndpoint: redis-cart:6379, conn-sec: 211427.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=7,QueuedItems=0,CompletedItems=8302574,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# ...
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5979ms elapsed, timeout is 5000ms), command=HGET, next: HGET 5a3671c2-f92c-4625-bfee-6bb849a18c8c, inst: 0, qu: 0, qs: 1195, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 12731, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 83087, serverEndpoint: redis-cart:6379, conn-sec: 212573.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=4,QueuedItems=0,CompletedItems=2426053,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5976ms elapsed, timeout is 5000ms), command=HGET, next: HGET 5a3671c2-f92c-4625-bfee-6bb849a18c8c, inst: 0, qu: 0, qs: 1197, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 12865, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 83089, serverEndpoint: redis-cart:6379, conn-sec: 212575.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=4,QueuedItems=0,CompletedItems=2426100,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5975ms elapsed, timeout is 5000ms), command=HGET, next: HGET 5a3671c2-f92c-4625-bfee-6bb849a18c8c, inst: 0, qu: 0, qs: 1203, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 13267, last-in: 54, cur-in: 0, sync-ops: 2, async-ops: 83095, serverEndpoint: redis-cart:6379, conn-sec: 212582.55, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-0(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=1,Free=32766,Min=1,Max=32767), POOL: (Threads=4,QueuedItems=0,CompletedItems=2426205,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# could not retrieve cart: rpc error: code = FailedPrecondition desc = Can't access cart storage. StackExchange.Redis.RedisTimeoutException: Timeout awaiting response (outbound=0KiB, inbound=0KiB, 5977ms elapsed, timeout is 5000ms), command=HGET, next: HGET 9b9d27e9-0a6c-4f51-a2b5-4c27866e910f, inst: 0, qu: 0, qs: 2391, aw: False, bw: SpinningDown, rs: ReadAsync, ws: Idle, in: 0, in-pipe: 0, out-pipe: 0, last-in: 0, cur-in: 0, sync-ops: 2, async-ops: 497823, serverEndpoint: redis-cart:6379, conn-sec: 212628.27, aoc: 1, mc: 1/1/0, mgr: 10 of 10 available, clientName: cartservice-2(SE.Redis-v2.6.122.38350), IOCP: (Busy=0,Free=1000,Min=1,Max=1000), WORKER: (Busy=2,Free=32765,Min=1,Max=32767), POOL: (Threads=3,QueuedItems=0,CompletedItems=8327699,Timers=4), v: 2.6.122.38350 (Please take a look at this article for some common client-side issues that can cause timeouts: https://stackexchange.github.io/StackExchange.Redis/Timeouts)
#    at cartservice.cartstore.RedisCartStore.GetCartAsync(String userId) in /app/cartstore/RedisCartStore.cs:line 248
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_23-00-00.parquet with 152935 records
# failed to complete the order: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp 10.233.61.165:5050: connect: connection refused"
# failed to complete the order: rpc error: code = Unavailable desc = transport is closing
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_02-00-00.parquet with 141808 records
# failed to complete the order: rpc error: code = Canceled desc = context canceled
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_13-00-00.parquet with 348172 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_00-00-00.parquet with 157774 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_19-00-00.parquet with 582851 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_08-00-00.parquet with 155081 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_07-00-00.parquet with 149028 records
# failed to complete the order: rpc error: code = Internal desc = shipping quote failure: failed to get shipping quote: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp 10.233.27.213:50051: i/o timeout"
# failed to complete the order: rpc error: code = Internal desc = shipping quote failure: failed to get shipping quote: rpc error: code = Unavailable desc = timed out waiting for server handshake
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_03-00-00.parquet with 121292 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_21-00-00.parquet with 298488 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_17-00-00.parquet with 456845 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_01-00-00.parquet with 155812 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_15-00-00.parquet with 355380 records
# failed to get product recommendations: rpc error: code = Canceled desc = context canceled
# could not retrieve currencies: rpc error: code = Canceled desc = context canceled
# failed to get product recommendations: rpc error: code = Unavailable desc = transport is closing
# failed to get product recommendations: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp 10.233.43.10:8080: i/o timeout"
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_09-00-00.parquet with 210149 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_18-00-00.parquet with 401160 records
# Processing ../phasetwo/2025-06-20/log-parquet/log_filebeat-server_2025-06-20_16-00-00.parquet with 422335 records
# could not retrieve product: rpc error: code = Unknown desc = Error 9001 (HY000): PD server timeout: start timestamp may fall behind safe point
# failed to get product recommendations: failed to get recommended product info (<PRODUCT_ID>): rpc error: code = Unknown desc = Error 9001 (HY000): PD server timeout: start timestamp may fall behind safe point
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_15-00-00.parquet with 409175 records
# failed to get ads: rpc error: code = DeadlineExceeded desc = context deadline exceeded
# failed to get product recommendations: rpc error: code = Unknown desc = Exception calling application: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.<PRODUCT_ID>
# 	details = "Connection reset by peer"
# 	debug_error_string = "{"created":"@<PRODUCT_ID>.<PRODUCT_ID>","description":"Error received from peer ipv4:10.233.54.177:3550","file":"src/core/lib/surface/call.cc","file_line":1055,"grpc_message":"Connection reset by peer","grpc_status":14}"
# >
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_20-00-00.parquet with 354818 records
# failed to do currency conversion for product <PRODUCT_ID>: rpc error: code = Canceled desc = context canceled
# failed to get shipping quote: failed to convert currency for shipping cost: rpc error: code = Canceled desc = context canceled
# could not convert currency for product <PRODUCT_ID>: rpc error: code = Canceled desc = context canceled
# failed to convert currency: rpc error: code = Canceled desc = context canceled
# failed to complete the order: rpc error: code = Internal desc = failed to prepare order: failed to convert price of "<PRODUCT_ID>" to EUR
# failed to convert currency: rpc error: code = Unavailable desc = transport is closing
# could not convert currency for product <PRODUCT_ID>: rpc error: code = Unavailable desc = transport is closing
# failed to complete the order: rpc error: code = Internal desc = failed to prepare order: failed to convert price of "<PRODUCT_ID>" to JPY
# failed to do currency conversion for product <PRODUCT_ID>: rpc error: code = Unavailable desc = transport is closing
# failed to complete the order: rpc error: code = Internal desc = failed to convert shipping cost to currency: failed to convert currency: rpc error: code = Unavailable desc = transport is closing
# failed to get shipping quote: failed to convert currency for shipping cost: rpc error: code = Unavailable desc = transport is closing
# failed to complete the order: rpc error: code = Internal desc = failed to prepare order: failed to convert price of "<PRODUCT_ID>" to CAD
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_17-00-00.parquet with 543510 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_11-00-00.parquet with 381980 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_01-00-00.parquet with 110149 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_13-00-00.parquet with 463036 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_23-00-00.parquet with 156787 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_10-00-00.parquet with 143191 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_12-00-00.parquet with 482916 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_14-00-00.parquet with 459379 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_19-00-00.parquet with 583112 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_03-00-00.parquet with 156253 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_00-00-00.parquet with 155012 records
# failed to add to cart: rpc error: code = FailedPrecondition desc = Can't access cart storage.
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_18-00-00.parquet with 576880 records
# failed to complete the order: rpc error: code = Unavailable desc = shipping error: shipment failed: rpc error: code = Unavailable desc = timed out waiting for server handshake
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_21-00-00.parquet with 304092 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_02-00-00.parquet with 153178 records
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_16-00-00.parquet with 503815 records
# failed to get ads: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp 10.233.8.174:9555: connect: connection refused"
# failed to get ads: rpc error: code = Unavailable desc = connection closed
# Processing ../phasetwo/2025-06-17/log-parquet/log_filebeat-server_2025-06-17_22-00-00.parquet with 154725 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_21-00-00.parquet with 307046 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_03-00-00.parquet with 157219 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_12-00-00.parquet with 462312 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_23-00-00.parquet with 156593 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_18-00-00.parquet with 514468 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_07-00-00.parquet with 112742 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_17-00-00.parquet with 522804 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_10-00-00.parquet with 351909 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_14-00-00.parquet with 456180 records
# failed to complete the order: rpc error: code = Internal desc = cart failure: failed to get user cart during checkout: rpc error: code = Unavailable desc = connection error: desc = "transport: Error while dialing dial tcp: lookup cartservice on 10.233.33.139:53: server misbehaving"
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_22-00-00.parquet with 153736 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_20-00-00.parquet with 506272 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_09-00-00.parquet with 205324 records
# Processing ../phasetwo/2025-06-27/log-parquet/log_filebeat-server_2025-06-27_16-00-00.parquet with 503350 records
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 24
#      21 df = pd.read_parquet(file)
#      22 print(f"Processing {file} with {len(df)} records")
# ---> 24 for index, row in df.iterrows():
#      25     if 'message' in row:
#      26         message = row['message']
#
# File /data/workspace/aiops2025/env/lib64/python3.11/site-packages/pandas/core/frame.py:1559, in DataFrame.iterrows(self)
#    1557 using_cow = using_copy_on_write()
#    1558 for k, v in zip(self.index, self.values):
# -> 1559     s = klass(v, index=columns, name=k).__finalize__(self)
#    1560     if using_cow and self._mgr.is_single_block:
#    1561         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File /data/workspace/aiops2025/env/lib64/python3.11/site-packages/pandas/core/series.py:436, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     433     return
#     435 is_pandas_object = isinstance(data, (Series, Index, ExtensionArray))
# --> 436 data_dtype = getattr(data, "dtype", None)
#     437 original_dtype = dtype
#     439 if isinstance(data, (ExtensionArray, np.ndarray)):
#
# KeyboardInterrupt:
