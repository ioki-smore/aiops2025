# %%
# for i in range(24):
#     trace = f"trace_jaeger-span_2025-04-30_{i:02d}-00-00.parquet"
#     df = pd.read_parquet("../data/sample/normal/trace-parquet/" + trace)
#     print(f"Processing {trace} with {len(df)} records")
#     for index, row in df.iterrows():
#         print(f"Index: {index}, Trace ID: {row['traceID']}, Span ID: {row['spanID']}, Operation Name: {row['operationName']}, tags: {row['tags']}")
#     print(df.head())
import glob
import pandas as pd # type: ignore
files = glob.glob("../phaseone/*/trace-parquet/*")
for file in files:
    df = pd.read_parquet(file)
    print(f"Processing {file} with {len(df)} records")
    for index, row in df.iterrows():
        tags = row["tags"]
        key = []
        for tag in tags:
            if isinstance(tag, dict) and "key" in tag and "value" in tag:
                key.append(tag['key'])
        if 'status.code' not in key and 'db.system' not in key and 'http.request.method' not in key:
            print(tags)

        # if len(row['references']) > 1:
            # print("error")

            # print(row['references'])
        # print(f"traceID\t{row['traceID']}\nspanID\t{row['spanID']}\noperationName\t{row['operationName']}\nreferences\t{row['references']}\nstartTimeMillis\t{row['startTimeMillis']}\nduration\t{row['duration']}\ntags\t{row['tags']}\nlogs\t{row['logs']}\nprocess\t{row['process']}")
        # tags = row['tags']
        # logs = row['logs']
        # for tag in tags:
        #     if tag.get("key") == "http.response.status_code" and str(tag.get("value")).startswith("5"):
        # cnt += 1
                # print(f"Index: {index}, Trace ID: {row['traceID']}, Span ID: {row['spanID']}, Operation Name: {row['operationName']}, tags: {row['tags']}")
        # for log in logs:
        #     print(log)
        # cnt += 1

        # print(df.head())
# [{'key': 'otel.library.name', 'type': 'string', 'value': 'OpenTelemetry.Instrumentation.StackExchangeRedis'}
#  {'key': 'otel.library.version', 'type': 'string', 'value': '1.0.0.10'}
#  {'key': 'db.system', 'type': 'string', 'value': 'redis'}
#  {'key': 'db.redis.flags', 'type': 'string', 'value': 'DemandMaster'}
#  {'key': 'db.statement', 'type': 'string', 'value': 'HMSET'}
#  {'key': 'net.peer.name', 'type': 'string', 'value': 'redis-cart'}
#  {'key': 'net.peer.port', 'type': 'int64', 'value': '6379'}
#  {'key': 'db.redis.database_index', 'type': 'int64', 'value': '0'}
#  {'key': 'peer.service', 'type': 'string', 'value': 'redis-cart:6379'}
#  {'key': 'span.kind', 'type': 'string', 'value': 'client'}
#  {'key': 'internal.span.format', 'type': 'string', 'value': 'otlp'}]

# [{'key': 'otel.library.name', 'type': 'string', 'value': 'OpenTelemetry.Instrumentation.AspNetCore'}
 # {'key': 'otel.library.version', 'type': 'string', 'value': '1.0.0.0'}
 # {'key': 'server.address', 'type': 'string', 'value': 'cartservice'}
 # {'key': 'server.port', 'type': 'int64', 'value': '7070'}
 # {'key': 'http.request.method', 'type': 'string', 'value': 'POST'}
 # {'key': 'url.scheme', 'type': 'string', 'value': 'http'}
 # {'key': 'url.path', 'type': 'string', 'value': '/hipstershop.CartService/GetCart'}
 # {'key': 'network.protocol.version', 'type': 'string', 'value': '2'}
 # {'key': 'user_agent.original', 'type': 'string', 'value': 'grpc-go/1.31.0'}
 # {'key': 'grpc.method', 'type': 'string', 'value': '/hipstershop.CartService/GetCart'}
 # {'key': 'grpc.status_code', 'type': 'string', 'value': '0'}
 # {'key': 'http.route', 'type': 'string', 'value': '/hipstershop.CartService/GetCart'}
 # {'key': 'http.response.status_code', 'type': 'int64', 'value': '200'}
 # {'key': 'span.kind', 'type': 'string', 'value': 'server'}
 # {'key': 'internal.span.format', 'type': 'string', 'value': 'otlp'}]

 # [{'key': 'rpc.system', 'type': 'string', 'value': 'grpc'}
 # {'key': 'rpc.service', 'type': 'string', 'value': 'hipstershop.RecommendationService'}
 # {'key': 'rpc.method', 'type': 'string', 'value': 'ListRecommendations'}
 # {'key': 'net.peer.ip', 'type': 'string', 'value': 'recommendationservice'}
 # {'key': 'net.peer.port', 'type': 'string', 'value': '8080'}
 # {'key': 'instrumentation.name', 'type': 'string', 'value': 'go.opentelemetry.io/otel/sdk/tracer'}
 # {'key': 'status.code', 'type': 'int64', 'value': '0'}
 # {'key': 'status.message', 'type': 'string', 'value': ''}
 # {'key': 'span.kind', 'type': 'string', 'value': 'client'}
 # {'key': 'internal.span.format', 'type': 'string', 'value': 'jaeger'}]
# Out:
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 145507 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163866 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 607836 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 560933 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 602162 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 477766 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 370813 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 139535 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 489467 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163669 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161795 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 495914 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 307333 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 521963 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161167 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 121002 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 152871 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 158862 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 482846 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 457885 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 517210 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163201 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 216200 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163336 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 607654 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 365260 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162322 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 551264 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 219166 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 400167 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 484460 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160436 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 494231 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 498454 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 592783 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 315955 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 86055 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 118214 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 482060 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 520957 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 478470 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162426 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 62772 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 368541 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162907 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 132714 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161627 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161534 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 490272 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160668 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 309461 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 484179 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 217563 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 506567 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163786 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 519799 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162748 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 485346 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 208960 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 158292 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 380578 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 434183 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 32231 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 398079 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 325167 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 485568 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 561974 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 483674 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 159549 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160695 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162197 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162187 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 100750 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160214 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160462 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 469693 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 108627 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 519553 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 217473 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 487085 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 394385 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 478719 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 514081 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163995 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160508 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163363 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 399438 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 486845 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 364690 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161544 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 217909 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160343 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 110533 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 155645 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162782 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 472910 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 114357 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 500726 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 555212 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 483501 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 514993 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 492060 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 120591 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 280731 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162919 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161267 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 454512 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 488087 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 514360 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161348 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160066 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161878 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 480985 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 408728 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 372054 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 156312 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 181764 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 486631 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 395609 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 159213 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 145290 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 501194 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160337 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 485329 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 535189 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 477823 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160265 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 503653 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162966 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 460273 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 516306 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 208742 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 478434 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 81879 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 553708 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 498424 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 488779 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 396965 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 96977 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 146552 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 159584 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 116686 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 337301 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 597729 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 356061 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 342564 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 555704 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161582 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161718 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 107495 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 587666 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 159879 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162016 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 200948 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 500523 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 218737 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 431802 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 496647 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 408139 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 164757 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 157999 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 310520 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 210547 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 140336 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 397760 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 163220 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 482639 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 475498 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162153 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 216669 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 146116 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 140751 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 367283 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 554626 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 477805 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 106399 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 593953 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 516516 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 161059 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 160669 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 480580 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 146692 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 514576 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 378987 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162625 records
# Processing trace_jaeger-span_2025-06-06_01-00-00.parquet with 162818 records
